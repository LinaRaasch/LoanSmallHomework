# %%
import pandas as pd
import numpy as np
import sklearn
location = 'loansmall.csv'
df = pd.read_csv(location)
df.head(None)
# Out:
#              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       1077501    1296599       5000         5000       4975.00000
# 1       1077430    1314167       2500         2500       2500.00000
# 2       1077175    1313524       2400         2400       2400.00000
# 3       1076863    1277178      10000        10000      10000.00000
# 4       1075358    1311748       3000         3000       3000.00000
# 5       1075269    1311441       5000         5000       5000.00000
# 6       1069639    1304742       7000         7000       7000.00000
# 7       1072053    1288686       3000         3000       3000.00000
# 8       1071795    1306957       5600         5600       5600.00000
# 9       1071570    1306721       5375         5375       5350.00000
# 10      1070078    1305201       6500         6500       6500.00000
# 11      1069908    1305008      12000        12000      12000.00000
# 12      1064687    1298717       9000         9000       9000.00000
# ...

# %%
df.shape
# Out:
# (194111, 74)

# %%
df.isnull().sum()
# Out:
# id                                  0
# member_id                           0
# loan_amnt                           0
# funded_amnt                         0
# funded_amnt_inv                     0
# term                                0
# int_rate                            0
# installment                         0
# grade                               0
# sub_grade                           0
# emp_title                       12177
# emp_length                       7722
# home_ownership                      0
# annual_inc                          4
# verification_status                 0
# issue_d                             0
# loan_status                         0
# pymnt_plan                          0
# url                                 0
# desc                           106340
# purpose                             0
# title                              19
# zip_code                            0
# addr_state                          0
# dti                                 0
# ...

# %%
df1=df.dropna(axis=1,how='all')
df1.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade       ...        next_pymnt_d  \
# 0     10.65       162.87     B        B2       ...                 NaN
# 1     15.27        59.83     C        C4       ...                 NaN
# 2     15.96        84.33     C        C5       ...                 NaN
# 3     13.49       339.31     C        C1       ...                 NaN
# 4     12.69        67.79     B        B5       ...              Feb-16
#
#   last_credit_pull_d collections_12_mths_ex_med  mths_since_last_major_derog  \
# ...

# %%
df2=df1.dropna()
df2.head(None)
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 42630   10089537   11941075       7500         7500           7500.0
# 42667   10159240   12010878      16000        16000          16000.0
# 42678   10159217   12010856      14125        14125          14125.0
# 42759    9847366   11699256      12000        12000          12000.0
# 43029    8978364   10780341      15600        15600          15600.0
# 43373   10138317    9101659      24000        24000          24000.0
# 43564   10068005   11919752      10000        10000          10000.0
# 44403    9924826   11776961      16500        16500          16500.0
# 44495   10145728   11997783      13000        13000          13000.0
# 44689   10096514   11948556      17000        17000          16850.0
# 44773   10086431   11938463      15000        15000          15000.0
# 44896   10136163   11988193      32875        32875          32875.0
# 45134   10065710   11917796       8000         8000           8000.0
# ...

# %%
pd.pivot_table(df, index= 'addr_state',columns='grade', values= "member_id", aggfunc='count', fill_value= 0,
              margins = True, margins_name= 'Total')
# Out:
# grade           A      B      C      D      E     F     G   Total
# addr_state
# AK             87    167    134     93     50    15     4     550
# AL            347    705    639    379    196    98    17    2381
# AR            210    440    382    217     97    29     6    1381
# AZ            675   1455   1136    608    309   136    40    4359
# CA           5134  10311   8081   4910   2150   936   209   31731
# CO            733   1322   1099    555    277   113    26    4125
# CT            538   1010    782    428    245    93    17    3113
# DC            120    211    147     98     56    24     5     661
# DE             69    175    140     91     34    14     3     526
# FL           2038   4228   3480   2055    859   388    98   13146
# GA           1039   2071   1587    890    424   194    68    6273
# HI            125    333    291    193     86    51     5    1084
# IA              2      2      2      4      1     2     0      13
# ...
